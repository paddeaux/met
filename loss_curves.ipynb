# %%
import pandas as pd
import matplotlib.pyplot as plt
import csv

gen_loss = pd.read_csv('/home/paddy/git/gen_loss.csv')

print(gen_loss)
gen_loss['batch_number'] = gen_loss['batch_number']/2
gen_256 = gen_loss[gen_loss['size']==256.0]

#critic_loss = pd.read_csv('home/paddy/git/critic_loss.csv')
#critic_loss['batch_number'] = critic_loss['batch_number']/2
#critic_256 = critic_loss[critic_loss['size']==256.0]
# Out:
#            size  epoch  batch_number       loss
# 0           4.0    0.0           0.0   0.640805
# 1           4.0    0.0           2.0   0.928621
# 2           4.0    0.0           4.0   0.734229
# 3           4.0    0.0           6.0   0.406303
# 4           4.0    0.0           8.0   0.399709
# ...         ...    ...           ...        ...
# 67420550  256.0   98.0       22574.0   9.603863
# 67420551  256.0   98.0       22576.0  10.718328
# 67420552  256.0   98.0       22578.0  13.314043
# 67420553  256.0   98.0       22580.0   7.995141
# 67420554  256.0   98.0       22582.0   5.376513
#
# [67420555 rows x 4 columns]

# %%
fig, ax = plt.subplots(1,1,figsize=(10,8))

#critic_256.plot.scatter(ax=ax, x='epoch', y='loss', c='orange',s=0.1)
gen_256.plot.scatter(ax=ax, x='epoch', y='loss', c='blue',s=0.1)

plt.show()

# %%
# Out:
#          size  epoch  batch_number       loss
# 214558  256.0    9.0           0.0  25.548592
# 214559  256.0    9.0           1.0  -4.655096
# 214560  256.0    9.0           2.0 -10.635320
# 214561  256.0    9.0           3.0  -3.116214
# 214562  256.0    9.0           4.0  14.691083
# ...       ...    ...           ...        ...
# 225845  256.0    9.0       11287.0   9.243605
# 225846  256.0    9.0       11288.0   6.630164
# 225847  256.0    9.0       11289.0   9.804345
# 225848  256.0    9.0       11290.0  -5.027360
# 225849  256.0    9.0       11291.0   8.698134
#
# [11292 rows x 4 columns]
